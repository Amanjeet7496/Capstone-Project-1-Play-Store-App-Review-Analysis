# %% [markdown]
# <a href="https://colab.research.google.com/github/Amanjeet7496/Capstone-Project-1-Play-Store-App-Review-Analysis/blob/main/Individual_Play_Store_App_Review_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  **Play Store App Review Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name**            - Amanjeet Kumar Singh

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The objective of this project was to analyze Play Store apps data and customer reviews to uncover key factors responsible for app engagement and success in the Android market. By exploring these datasets, actionable insights were derived to guide app developers in capturing the market and achieving their business goals.
#
# The Play Store apps dataset provided valuable information about each app, including its category, rating, size, and more. The customer reviews dataset contained feedback and sentiments expressed by users, offering insights into user experiences and preferences.
#
# The analysis began with an exploration of the top app categories with the highest number of apps. This information helped developers identify popular and trending areas in the market and make informed decisions regarding app development.
#
# The correlation between app size and the number of installations was investigated to determine if there was any relationship between these factors.
#
# The customer reviews dataset underwent sentiment analysis to understand the overall sentiment expressed by users.The average sentiment polarity for each app was calculated to determine the overall sentiment associated with specific apps.The relationship between app ratings and sentiment subjectivity was also examined to explore any correlation between user ratings and the subjective nature of their feedback.
#
# Throughout the analysis, various visualizations were utilized to present the findings effectively like Bar charts, histograms, scatter plots, pie charts, and heatmaps were used to illustrate patterns, relationships, and distributions in data.
#
# In conclusion, this project demonstrated the value of Play Store apps data and customer reviews in driving app-making businesses to success. Through exploration of the datasets, actionable insights were derived to guide developers in making informed decisions and capturing the Android market effectively.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Amanjeet7496/Capstone-Project-1-Play-Store-App-Review-Analysis/blob/8b400c00933b28b544a134365775e37ca0ae9df8/Individual_Play_Store_App_Review_Analysis.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The objective of this project is to analyze the Play Store apps data and user reviews to identify key factors that influence app engagement and success. The problem statement can be defined as follows:
#
# **Given the Play Store apps data and user reviews dataset, the task is to:**
#
# * Perform exploratory data analysis (EDA) to gain insights into the characteristics of successful apps.
# * Identify the factors that contribute to high user ratings and positive user sentiments.
# * Analyze the relationship between app size, category, and the number of installations to understand user preferences.
# * Determine the impact of app pricing on user engagement and popularity.
# * Investigate the effect of app updates and compatibility with different Android versions on user satisfaction.
# * Explore the relationship between user reviews, sentiment polarity, and subjectivity to understand user feedback patterns.
# * Provide actionable recommendations for developers to improve app engagement and maximize success in the Android market.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# ***Maximize app engagement, user satisfaction, and revenue generation by leveraging insights from Play Store apps data and user reviews.***

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
Play_Store_Data = pd.read_csv("/content/Play Store Data.csv")

# %%
User_Reviews = pd.read_csv("/content/User Reviews.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First 
Play_Store_Data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
User_Reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns 
Play_Store_Data.shape
# Out:
# (10841, 13)

# %%
User_Reviews.shape
# Out:
# (64295, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
Play_Store_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
User_Reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(Play_Store_Data[Play_Store_Data.duplicated()])
# Out:
# 483

# %%
len(User_Reviews[User_Reviews.duplicated()])
# Out:
# 33616

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(Play_Store_Data.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
print(User_Reviews.isnull().sum())
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
sns.heatmap(Play_Store_Data.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
sns.heatmap(User_Reviews.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset given is a dataset from Play Store App Review Analysis, and we have to analysis the insights behind it.
#
# The Play Store dataset has 10841 rows and 13 columns.
#
# *Mising Values*
# * Rating:- 1474
# * Type:- 1
# * Content Rating:- 1
# * Current Ver:-8
# * Android Ver:-3
#
# Duplicate values in the dataset 483
#
# The User Reviews dataset has 64295 rows and 5 columns.
#
# *Mising Values*
# * Translated_Reviews:- 26868
# * Sentiment:- 26863
# * Sentiment_polarity:- 26863
# * Sentiment_subjectivity:-26863
#
# Duplicate values in the dataset 33616

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
Play_Store_Data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
User_Reviews.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
Play_Store_Data.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
User_Reviews.describe(include='all')
# Out:
#                         App Translated_Review Sentiment  Sentiment_Polarity  \
# count                 64295             37427     37432        37432.000000
# unique                 1074             27994         3                 NaN
# top     Angry Birds Classic              Good  Positive                 NaN
# freq                    320               247     23998                 NaN
# mean                    NaN               NaN       NaN            0.182146
# std                     NaN               NaN       NaN            0.351301
# min                     NaN               NaN       NaN           -1.000000
# 25%                     NaN               NaN       NaN            0.000000
# 50%                     NaN               NaN       NaN            0.150000
# 75%                     NaN               NaN       NaN            0.400000
# max                     NaN               NaN       NaN            1.000000
#
#         Sentiment_Subjectivity
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# *Dataset Description:*
#
# ***The dataset consists of two separate datasets related to Play Store apps:***
#
# **Play Store Apps Data**:
#
# **Columns:**
#
# * **App**: Name of the application
#
# * **Category:** Category to which the app belongs (e.g., Games, Social, Tools, etc.)
#
# * **Rating:** User rating of the app (ranges from 1 to 5)
#
# * **Reviews:** Number of user reviews for the app
#
# * **Size:** Size of the app in megabytes (MB)
#
# * **Installs:** Number of user downloads/installs for the app
#
# * **Type:** Indicates whether the app is free or paid
#
# * **Price:**  Price of the app (if it is a paid app)
#
# * **Content Rating :** Age group to which the app is targeted (e.g., Everyone, Teen,
# Mature, etc.)
#
# * **Genres:** Genre(s) to which the app belongs (e.g., Action, Puzzle, Social Networking, etc.)
#
# * **Last Updated:** Date when the app was last updated on the Play Store
#
# * **Current Ver:** Current version of the app
#
# * **Android Ver:** Minimum required Android version to run the app
#
#
# ****User Reviews of Android Apps:****
#
# **Columns:**
#
# * **App:** Name of the application
#
# * **Translated_Review:** User review for the app (translated to English)
#
# * **Sentiment:** Sentiment of the user review (Positive, Negative, Neutral)
#
# * **Sentiment_Polarity:** Polarity score of the user review (-1 to 1, where -1
# indicates negative sentiment and 1 indicates positive sentiment)
#
# * **Sentiment_Subjectivity:** Subjectivity score of the user review (0 to 1, where 0 indicates objective and 1 indicates subjective)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in Play_Store_Data.columns.tolist():
  print("No. of unique values in ",i,"is",Play_Store_Data[i].nunique(),".")
# Out:
# No. of unique values in  App is 9660 .
# No. of unique values in  Category is 34 .
# No. of unique values in  Rating is 40 .
# No. of unique values in  Reviews is 6002 .
# No. of unique values in  Size is 462 .
# No. of unique values in  Installs is 22 .
# No. of unique values in  Type is 3 .
# No. of unique values in  Price is 93 .
# No. of unique values in  Content Rating is 6 .
# No. of unique values in  Genres is 120 .
# No. of unique values in  Last Updated is 1378 .
# No. of unique values in  Current Ver is 2832 .
# No. of unique values in  Android Ver is 33 .

# %%
for i in User_Reviews.columns.tolist():
  print("No. of unique values in ",i,"is",User_Reviews[i].nunique(),".")
# Out:
# No. of unique values in  App is 1074 .
# No. of unique values in  Translated_Review is 27994 .
# No. of unique values in  Sentiment is 3 .
# No. of unique values in  Sentiment_Polarity is 5410 .
# No. of unique values in  Sentiment_Subjectivity is 4474 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Create a copy of the current dataset and assigning to df
df = Play_Store_Data.copy()
df1 = User_Reviews.copy()

# %%
# Filling Missing Values in Play Store Dataset.
df['Rating'].fillna(df['Rating'].mean(), inplace = True)
df['Rating'].isnull().sum()
# Out:
# 0

# %%
# Drop duplicates in play store dataset.
df.drop_duplicates(inplace = True)
df.drop_duplicates(subset='App',inplace = True)

# %%
# Drop all null value.
df.dropna(inplace = True)
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
# Fill missing value in sentiment in User Reviews.
df1 = df1[~df1['Sentiment'].isnull()]
df1.dropna(inplace = True)
df1.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
# 1. Analyze the distribution of app ratings
app_ratings = df['Rating']
average_rating = df.mean()
print("Average App Rating:", average_rating)
# Out:
# Average App Rating: Rating     4.176346
# Reviews         inf
# dtype: float64
# <ipython-input-27-09bf00c87cf0>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   average_rating = df.mean()

# %%
# 2. Calculate the average sentiment polarity for each app
average_polarity = df1.groupby('App')['Sentiment_Polarity'].mean()
print("Average Sentiment Polarity by App:")
print(average_polarity)
# Out:
# Average Sentiment Polarity by App:
# App
# 10 Best Foods for You                                 0.470733
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                      0.392405
# 11st                                                  0.185943
# 1800 Contacts - Lens Store                            0.318145
# 1LINE – One Line with One Touch                       0.196290
#                                                         ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals    0.101622
# Hotspot Shield Free VPN Proxy & Wi-Fi Security        0.251765
# Hotstar                                               0.038178
# Hotwire Hotel & Car Rental App                        0.187029
# Housing-Real Estate & Property                       -0.021427
# Name: Sentiment_Polarity, Length: 865, dtype: float64

# %%
# 3. Analyze the relationship between app ratings and sentiment subjectivity
ratings_subjectivity = pd.merge(df[['App', 'Rating']], df1[['App', 'Sentiment_Subjectivity']], on='App')
correlation = ratings_subjectivity['Rating'].corr(ratings_subjectivity['Sentiment_Subjectivity'])
print("Correlation between App Ratings and Sentiment Subjectivity:", correlation)
# Out:
# Correlation between App Ratings and Sentiment Subjectivity: 0.06875823267975349

# %%
# 4. Calculate the sentiment distribution in user reviews
sentiment_distribution = df1['Sentiment'].value_counts()
print("Sentiment Distribution:")
print(sentiment_distribution)
# Out:
# Sentiment Distribution:
# Positive    23998
# Negative     8271
# Neutral      5158
# Name: Sentiment, dtype: int64

# %%
# 5. Identify the top categories with the highest number of apps
top_categories = df['Category'].value_counts().head(5)
print("Top Categories:")
print(top_categories)
# Out:
# Top Categories:
# FAMILY      1828
# GAME         959
# TOOLS        825
# BUSINESS     420
# MEDICAL      395
# Name: Category, dtype: int64

# %%
# 6. Identify apps with the most positive sentiment polarity
top_positive_apps = average_polarity.nlargest(5)
print("Top Apps with Positive Sentiment Polarity:")
print(top_positive_apps)
# Out:
# Top Apps with Positive Sentiment Polarity:
# App
# HomeWork                                             1.000000
# Google Slides                                        0.933333
# Daily Workouts - Exercise Fitness Routine Trainer    0.800000
# Bed Time Fan - White Noise Sleep Sounds              0.781250
# Cameringo Lite. Filters Camera                       0.770269
# Name: Sentiment_Polarity, dtype: float64

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Bar chart - Top Categories
top_categories = df['Category'].value_counts().head(5)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_categories.index, y=top_categories.values)
plt.title('Top Categories')
plt.xlabel('Category')
plt.ylabel('Number of Apps')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen to visualize the top categories in the Play Store apps data. It is effective in comparing the number of apps in different categories and identifying the most popular categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides insights into the distribution of apps across different categories. It highlights the top categories with the highest number of apps. This information helps businesses understand the competitive landscape and identify popular areas for app development.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights from the bar chart can have a positive business impact. By knowing the top categories, businesses can focus their resources and efforts on developing apps in those categories, targeting a larger user base and increasing their chances of success. It allows businesses to align their app development strategy with user preferences and market demand, leading to improved user engagement, increased downloads, and potentially higher revenue generation.

# %% [markdown]
# #### Chart - 2

# %%
# Histogram - App Ratings Distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['Rating'].dropna(), bins=20, kde =True)
plt.title('App Ratings Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# :The histogram was chosen to visualize the distribution of app ratings. Histograms are effective for displaying the frequency or count of data within different rating bins. It provides a clear visual representation of the distribution and helps identify any patterns or trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the histogram, we can observe the distribution of app ratings. The chart displays the count of ratings within different rating intervals (bins). It allows us to identify the most common or prevalent ratings, as well as any outliers or unusual patterns in the distribution.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the distribution of app ratings can help create a positive business impact. Understanding the distribution can provide valuable information for app developers and businesses.
#
# Negative growth insights can arise if the histogram shows a significant concentration of low ratings or a skewed distribution towards negative ratings. This indicates that users are dissatisfied with the app, leading to potential negative consequences for the business.

# %% [markdown]
# #### Chart - 3

# %%
# Line chart - App Ratings vs. Sentiment Subjectivity
ratings_subjectivity = pd.merge(df[['App', 'Rating']], df1[['App', 'Sentiment_Subjectivity']], on='App')
plt.figure(figsize=(10, 6))
sns.lineplot(x='Rating', y='Sentiment_Subjectivity', data=ratings_subjectivity)
plt.title('App Ratings vs. Sentiment Subjectivity')
plt.xlabel('App Rating')
plt.ylabel('Sentiment Subjectivity')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a line chart because it is suitable for showing the relationship between two continuous variables over a continuous range. In this case, we are comparing the app ratings (which can range from 1 to 5) with the sentiment subjectivity

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights from the chart:
#
# The chart shows how the sentiment subjectivity varies across different app ratings.
# We can observe the trend and pattern of sentiment subjectivity as the app ratings increase or decrease.
# If the line has an upward or downward trend, it indicates a relationship between app ratings and sentiment subjectivity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact by providing an understanding of how app ratings relate to the sentiment subjectivity of user reviews. This information can be useful in several ways:
#
# Identifying the correlation between high app ratings and lower sentiment subjectivity can indicate that users are generally satisfied with the app and express their opinions objectively.
# Recognizing the correlation between lower app ratings and higher sentiment subjectivity might imply that users tend to express more subjective opinions when they are dissatisfied with the app.
# Businesses can use this information to evaluate the impact of app updates, changes, or new features on user sentiment subjectivity.
# By analyzing the sentiment subjectivity in relation to app ratings, companies can gain insights into user satisfaction and make informed decisions to improve their apps and address potential issues.

# %% [markdown]
# #### Chart - 4

# %%
# Pie chart: Sentiment distribution in user reviews
plt.figure(figsize=(8, 6))
sentiment_distribution = df1['Sentiment'].value_counts()
plt.pie(sentiment_distribution, labels=sentiment_distribution.index, autopct='%1.1f%%', startangle=90)
plt.title("Sentiment Distribution in User Reviews")
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart was chosen to visualize the sentiment distribution in user reviews because it effectively displays the proportions and relative distribution of different sentiment categories. The use of colors and labels allows for easy interpretation of the sentiment distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart provides insights into the sentiment distribution in user reviews. By analyzing the chart, we can identify the proportion of positive, negative, and neutral sentiments expressed by users. This information helps understand the overall sentiment trends and the general perception of the app among users

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from the sentiment distribution in user reviews can have a positive business impact. They provide valuable information about user satisfaction, feedback, and sentiment towards the app. By understanding the sentiment distribution, businesses can identify areas that need improvement, address negative feedback, and capitalize on positive sentiment to enhance the app's overall user experience. This, in turn, can lead to increased user engagement, customer loyalty, positive word-of-mouth, and ultimately drive business growth.
#
# If the sentiment distribution shows a significant proportion of negative sentiments, it can be an indication of potential issues or dissatisfaction among users. Negative sentiments might suggest problems with app functionality, usability, or overall user experience. If these insights are not addressed and improvements are not made promptly, it can lead to negative growth as users may become dissatisfied, uninstall the app, or leave negative reviews, resulting in decreased user engagement, retention, and potential loss of customers.

# %% [markdown]
# #### Chart - 5

# %%
# Scatter plot - App Size vs. Number of Installs
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Size', y='Installs', data=df)
plt.title('App Size vs. Number of Installs')
plt.xlabel('App Size (MB)')
plt.ylabel('Number of Installs')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot was chosen to visualize the correlation between app size and the number of installations. Scatter plots are effective in displaying the relationship between two numerical variables and identifying any patterns or trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the scatter plot, we can observe the following insights:
#
# * There is a positive correlation between app size and the number of installations. As the app size increases, there is generally a higher number of installations.
# * However, there is a wide range of installations for apps of different sizes. Some smaller apps have a significant number of installations, while larger apps may have a lower number of installations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact. By understanding the correlation between app size and the number of installations, app-making businesses can make informed decisions:
#
# * Developers can optimize app sizes based on the target audience's preferences and the impact on installations. It can help strike a balance between offering feature-rich apps and considering storage constraints on users' devices.
# * Businesses can assess the trade-off between app size and potential user base, determining the size threshold beyond which installations may decline. This insight can inform app development strategies and guide decision-making processes.
#
# *Insights leading to negative growth:*
# There may be potential insights leading to negative growth, such as:
#
# * Excessive app sizes that deter users from installing or keeping the app due to limited storage capacity on their devices.
# * If there is a significant proportion of smaller apps with high installations, it could indicate a preference for lightweight, specialized apps, potentially impacting the growth of larger, feature-rich apps.

# %% [markdown]
# #### Chart - 6

# %%
# Bar chart: Average sentiment polarity by app
plt.figure(figsize=(10, 6))
average_polarity = df1.groupby('App')['Sentiment_Polarity'].mean().nlargest(10)
sns.barplot(x=average_polarity.values, y=average_polarity.index, orient='h')
plt.title("Average Sentiment Polarity by App")
plt.xlabel("Average Sentiment Polarity")
plt.ylabel("App")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a horizontal bar chart to visualize the average sentiment polarity by app. This type of chart is suitable for comparing the sentiment polarity values across different apps. The horizontal orientation allows for easy reading of the app names on the y-axis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides insights into the average sentiment polarity of different apps. By analyzing the bar heights, we can identify apps that have the highest average sentiment polarity. These apps are likely to have a more positive sentiment and favorable user reviews compared to others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can have a positive business impact. Apps with a higher average sentiment polarity indicate that users generally have a positive sentiment towards those apps. This suggests that these apps are well-received and likely to attract more users, leading to increased user engagement, higher app ratings, and potentially higher revenue for the business.
#
# It is not possible to determine negative growth solely based on the average sentiment polarity chart. The chart only provides information about the sentiment polarity of different apps, indicating positive sentiment. However, to assess negative growth, it would require analyzing other factors such as decreasing app ratings, negative user reviews, declining installations, or a decrease in user engagement over time. Simply looking at the average sentiment polarity alone does not provide sufficient information to determine negative growth.

# %% [markdown]
# #### Chart 7- Correlation Heatmap

# %%
# Heatmap: Correlation between app ratings and sentiment subjectivity
plt.figure(figsize=(8, 6))
ratings_subjectivity = pd.merge(df[['App', 'Rating']], df1[['App', 'Sentiment_Subjectivity']], on='App')
correlation = ratings_subjectivity[['Rating', 'Sentiment_Subjectivity']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title("Correlation between App Ratings and Sentiment Subjectivity")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The heatmap was chosen as it provides a visual representation of the correlation between app ratings and sentiment subjectivity. The color-coded cells in the heatmap allow for easy interpretation of the strength and direction of the correlation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap reveals the correlation between app ratings and sentiment subjectivity. Positive values indicate a positive correlation, while negative values suggest a negative correlation. The strength of the correlation can be interpreted based on the intensity of the color. The insight derived from the chart is the degree of relationship between app ratings and the subjective nature of user sentiments.

# %% [markdown]
# #### Chart 8 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df1)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *The pair plot* was chosen to visualize the relationships between multiple variables in the dataset. It allows for a comprehensive analysis of the pairwise interactions and correlations among the variables, providing a holistic view of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the pair plot, we can observe the scatter plots for each combination of variables and the histograms for each individual variable. The insights that can be derived from the chart include:
#
# Identifying any significant positive or negative correlations between variables.
# Observing the distribution and spread of the variables.
# Detecting any outliers or unusual patterns.
# Exploring potential nonlinear relationships or clusters among the variables.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# *Solution to Business Objective:*
#
# *Understanding User Preferences:*
#
# * Focus on the top app categories with the highest number of apps to identify * popular and trending categories.
# * Allocate resources and development efforts towards those categories to meet user demands and preferences.
# * Conduct market research and user surveys to gain deeper insights into user preferences and identify potential gaps in the market.
#
# *Improving App Engagement:*
#
# * Analyze user reviews and feedback to identify common pain points and areas of improvement.
# * Prioritize addressing those issues through app updates, bug fixes, and feature enhancements.
# * Enhance the user interface, navigation, and overall user experience to increase engagement and satisfaction.
# * Implement personalized recommendations and notifications to keep users engaged with the app.
# *Maximizing User Base:*
#
# * Identify patterns and preferences related to app size, category, and number of installations.
# * Use this information to target specific user segments and optimize app offerings accordingly.
# * Utilize targeted marketing and advertising campaigns to reach and attract a larger user base.
# * Consider localization and language support to expand the app's reach to different regions and demographics.
# *Pricing Strategy:*
#
# * Analyze the relationship between app pricing, user engagement, and popularity.
# * Determine optimal pricing points based on market research, competitor analysis, and user willingness to pay.
# * Offer freemium or trial versions to entice users and provide value before asking for paid subscriptions or in-app purchases.
# * Regularly monitor and adjust pricing strategies based on user feedback and market dynamics.
#
# *Enhancing User Experience:*
#
# * Stay updated with the latest Android versions and ensure app compatibility for a wider user base.
# * Continuously release app updates with bug fixes, performance improvements, and new features.
# * Encourage user feedback and reviews to understand user experiences and address any issues promptly.
# * Incorporate user-centered design principles to create a seamless and intuitive app interface.
#
# *User Feedback Analysis:*
#
# * Analyze sentiment polarity and subjectivity in user reviews to identify positive and negative aspects of the app.
# * Address negative feedback and improve areas of concern to enhance the overall app experience.
# * Leverage positive reviews as testimonials and social proof to attract new users.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * Play Store apps data and user reviews provide valuable insights for app-making businesses to understand user preferences, improve app engagement, and drive success in the Android market.
#
# * Analyzing the top app categories helps identify popular and trending areas for app development and optimization.
#
# * User feedback analysis enables businesses to address pain points, enhance the user experience, and increase app engagement and satisfaction.
#
# * Understanding the correlation between app size, number of installations, and user preferences helps in targeting specific user segments and optimizing app offerings.
#
# * By leveraging the insights gained from the analysis, businesses can make informed decisions to maximize user base, optimize pricing strategies, and continuously improve app features and functionalities, leading to positive business impact and increased revenue generation.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
